# %% [markdown]
# #**Estatistica Descritiva**

# %% [markdown]
# **Conjunto de dados**:
#
# Dra. Isabela Mendes é biológa especialista em observar pinguins nas regiões polares e percebeu que existem 3 tipos de pinguins, sendo possível identificar com algumas características.
#
# Essa identificação é importante para compreender suas populações, comportamentos e os impactos. Porém, essa tarefa torna-se desafiadora quando é realizada individualmente consumindo muito tempo, muitas vezes requerendo a análise minuciosa.
#
# Determinada a superar esses obstáculos ela acredita que a ciência de dados pode ajudar na identificação automática dos pinguins.
#
# **Fonte dos dados:** [Pinguins Palmer](https://github.com/mwaskom/seaborn-data/blob/master/penguins.csv)

# %%
# Importações
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit

# %%
#carregando o conjunto de dados
df= pd.read_csv('/content/pinguins_processado.csv',sep =';')

# %% [markdown]
# #**Amostra Estratificada**

# %%
#caracteristicas previsoras
features = df.iloc[:,1:-1]
label = df.iloc[:,0]

# %%
#numero de amostras aleatorias
n_samples = 150

# %%
#criando variavel com amostra estratificada
stratified_split = StratifiedShuffleSplit(n_splits =1, test_size=n_samples)
#Realize a amostragem estratificada
for train_index, test_index in stratified_split.split(features, label):
  features_stratified, label_stratified = features.iloc[test_index,:], label.iloc[test_index]

# %%
#concatenando os dados
df2 = features_stratified
df2 = df2.assign(species= label_stratified)

# %% [markdown]
# #**Mapeando tipo de dada**

# %%
#Dicionário de dados
dicionario = {'variavel': ['species',
                           'bill_length_mm',
                           'body_mass_g'],
              'descricao': ['Classe da espécies',
                            'Comprimento do bico em milímetro',
                            'Peso em gramas'],
              'tipo':['Nonimal',
                      'Contínua',
                      'Discreta']}

dicionario = pd.DataFrame.from_dict(dicionario)

# %% [markdown]
# #**EStatistica básica**

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# #**Visualização de dados**

# %%
sns.histplot(df.bill_depth_mm)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(data = df, x= 'body_mass_g', hue = 'species' )
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(df.bill_length_mm,kde=True)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(df.bill_length_mm, kde = True, bins = 20)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
# Criando histograma com a densidade agrupando dados e adicionando título no gráfico e nos eixos
sns.histplot(df.bill_length_mm, kde = True, bins = 20, color="#102C57")
plt.xlabel('Comprimento do bico')
plt.ylabel('frequencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #**Diagrama de caixa**

# %%
sns.boxplot(df)
plt.title('dataframe')
plt.show()

# %%
sns.boxplot(data = df, x='bill_depth_mm', y= 'species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='species'>
